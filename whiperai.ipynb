# %%
# pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.9/792.9 kB 634.2 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for numba from https://files.pythonhosted.org/packages/f3/67/70d0fd1901971096c773bf89747c16023dbe8ce3cce1b7d2e94a87390ca7/numba-0.57.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/fa/07/c6980120967a9fc76138eddd583d6ac47dd072922d6f66d7d502f6f9a964/numpy-1.25.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 MB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /private/var/folders/0d/srwhm0y53j14k9ypbh_kj7v40000gn/T/pip-req-build-qaxc4ci5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /private/var/folders/0d/srwhm0y53j14k9ypbh_kj7v40000gn/T/pip-req-build-qaxc4ci5
#   Resolved https://github.com/openai/whisper.git to commit b91c907694f96a3fb9da03d4bbdc83fbcd3a40a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.6/735.6 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.3.1
#     Uninstalling tiktoken-0.3.1:
#       Successfully uninstalled tiktoken-0.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !whisper "output_audio.wav" --model medium.en
# Out:
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/timing.py:58: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def backtrace(trace: np.ndarray):
# 100%|█████████████████████████████████████| 1.42G/1.42G [05:19<00:00, 4.78MiB/s]
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:07.520]  Hello friends and welcome to another video tutorial by GeeksforGeeks. In this video,
# ...

# %%
# !whisper "output_audio.wav" --model tiny.en
# Out:
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/timing.py:58: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def backtrace(trace: np.ndarray):
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:31<00:00, 2.40MiB/s]
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:07.000]  Hello friends and welcome to another video tutorial by GeeksforGeeks.
# ...

# %%
import whisper
model = whisper.load_model("tiny")

# %%
result = model.transcribe("output_audio.wav")
result["text"]
# Out:
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
result['segments']
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 7.0,
#   'text': ' Hello friends and welcome to another video tutorial by Geeksorgames.',
#   'tokens': [50364,
#    2425,
#    1855,
#    293,
#    2928,
#    281,
#    1071,
#    960,
#    7073,
#    538,
#    2876,
#    24785,
#    4646,
#    1632,
#    13,
#    50714],
#   'temperature': 0.0,
#   'avg_logprob': -0.4021920290860263,
#   'compression_ratio': 1.6093023255813954,
#   'no_speech_prob': 0.41225922107696533},
#  {'id': 1,
#   'seek': 0,
#   'start': 7.0,
#   'end': 11.44,
#   'text': ' In this video we will see how to search in an almost sorted element.',
#   'tokens': [50714,
#    682,
#    341,
#    960,
#    321,
#    486,
#    536,
#    577,
#    281,
#    3164,
#    294,
#    364,
#    1920,
#    25462,
#    4478,
#    13,
#    50936],
#   'temperature': 0.0,
#   'avg_logprob': -0.4021920290860263,
#   'compression_ratio': 1.6093023255813954,
#   'no_speech_prob': 0.41225922107696533},
#  {'id': 2,
# ...

# %%
import pandas as pd
speech = pd.DataFrame.from_dict(result['segments'])
speech.head()
# Out:
#    id  seek  start    end                                               text  \
# 0   0     0   0.00   7.00   Hello friends and welcome to another video tu...
# 1   1     0   7.00  11.44   In this video we will see how to search in an...
# 2   2     0  11.44  12.44                                 Problem statement.
# 3   3     0  12.44  17.56   Given an array which is sorted but after sort...
# 4   4     0  17.56  23.12   the adjacent positions, that is, Iat element ...
#
#                                               tokens  temperature  \
# 0  [50364, 2425, 1855, 293, 2928, 281, 1071, 960,...          0.0
# 1  [50714, 682, 341, 960, 321, 486, 536, 577, 281...          0.0
# 2                    [50936, 11676, 5629, 13, 50986]          0.0
# 3  [50986, 18600, 364, 10225, 597, 307, 25462, 45...          0.0
# 4  [51242, 264, 24441, 8432, 11, 300, 307, 11, 28...          0.0
#
#    avg_logprob  compression_ratio  no_speech_prob
# 0    -0.402192           1.609302        0.412259
# ...

# %%
result = model.transcribe("cheatsheet.mp4")
result["text"]
# Out:
# /Users/pranaymishra/anaconda3/envs/Edufy/lib/python3.10/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...
